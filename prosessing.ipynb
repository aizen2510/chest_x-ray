# %%
import os
import cv2 as cv

img = r"C:\code\cnnt_model\chest_xray"

# resizing ve 224, 224 de su dung model ResNet50
# resizing
for i,j,k in os.listdir():
    for f in os.listdir(k):
        img = cv.imread(os.path.join(img,f))
        img = cv.resize(img,(224,224))
        print(f"save")

# %%
# Normalization

for i in img:
    i/225

# %%
#Data Augmentation
